# %%
# https://keras.io/examples/nlp/question_answering/

# %%
# ! pip install datasets

# %%
import pandas as pd
from datasets import Dataset
import json

profiles = []
with open("data/courses_exams/data/profiles.json", "r") as json_file:
    profiles = json.load(json_file)
for item in profiles:
    file_name = item["context_file"]
    answers = item["answers"]["text"]
    file_name = f"data/courses_exams/{file_name}"
    context = ""
    with open(file_name, "r") as f:
        context = f.read()
    item['context'] = context
    
    indexes = []
    for answer in answers:
        index = context.index(answer)
        indexes.append(index)
    item["answers"]["answer_start"] = indexes

with open("courses_exams_profiles_dump.json", "w") as json_file:
    json.dump(profiles, json_file)

datasets = Dataset.from_list(profiles)

# %%
from transformers import AutoTokenizer

# model_checkpoint = "bert-large-cased-whole-word-masking"
# model_checkpoint = "bert-large-cased"
# model_checkpoint = "bert-base-cased"
model_checkpoint = "distilbert-base-uncased"

tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

# %%
max_length = 896  # The maximum length of a feature (question and context)
doc_stride = (
    128  # The authorized overlap between two part of the context when splitting
)

# %%
# from transformers import AutoTokenizer

# model_checkpoint = "distilbert-base-cased"

# # tokenizer2 = AutoTokenizer.from_pretrained(model_checkpoint)
# tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

# max_length = 384  # The maximum length of a feature (question and context)
# doc_stride = (
#     128  # The authorized overlap between two part of the context when splitting
# )

def prepare_train_features(examples):
    # Tokenize our examples with truncation and padding, but keep the overflows using a
    # stride. This results in one example possible giving several features when a context is long,
    # each of those features having a context that overlaps a bit the context of the previous
    # feature.
    examples["question"] = [q.lstrip() for q in examples["question"]]
    examples["context"] = [c.lstrip() for c in examples["context"]]
    
    from transformers import AutoTokenizer

    model_checkpoint = "distilbert-base-uncased"
    # model_checkpoint = "bert-base-cased"
    tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)
    max_length = 896  # The maximum length of a feature (question and context)
    doc_stride = (
        128  # The authorized overlap between two part of the context when splitting
    )
        
    tokenized_examples = tokenizer(
        examples["question"],
        examples["context"],
        truncation="only_second",
        max_length=max_length,
        stride=doc_stride,
        return_overflowing_tokens=True,
        return_offsets_mapping=True,
        padding="max_length",
    )

    # Since one example might give us several features if it has a long context, we need a
    # map from a feature to its corresponding example. This key gives us just that.
    sample_mapping = tokenized_examples.pop("overflow_to_sample_mapping")
    # The offset mappings will give us a map from token to character position in the original
    # context. This will help us compute the start_positions and end_positions.
    offset_mapping = tokenized_examples.pop("offset_mapping")

    # Let's label those examples!
    tokenized_examples["start_positions"] = []
    tokenized_examples["end_positions"] = []

    for i, offsets in enumerate(offset_mapping):
        # We will label impossible answers with the index of the CLS token.
        input_ids = tokenized_examples["input_ids"][i]
        cls_index = input_ids.index(tokenizer.cls_token_id)

        # Grab the sequence corresponding to that example (to know what is the context and what
        # is the question).
        sequence_ids = tokenized_examples.sequence_ids(i)

        # One example can give several spans, this is the index of the example containing this
        # span of text.
        sample_index = sample_mapping[i]
        answers = examples["answers"][sample_index]
        # If no answers are given, set the cls_index as answer.
        if len(answers["answer_start"]) == 0:
            tokenized_examples["start_positions"].append(cls_index)
            tokenized_examples["end_positions"].append(cls_index)
        else:
            # Start/end character index of the answer in the text.
            start_char = answers["answer_start"][0]
            end_char = start_char + len(answers["text"][0])

            # Start token index of the current span in the text.
            token_start_index = 0
            while sequence_ids[token_start_index] != 1:
                token_start_index += 1

            # End token index of the current span in the text.
            token_end_index = len(input_ids) - 1
            while sequence_ids[token_end_index] != 1:
                token_end_index -= 1

            # Detect if the answer is out of the span (in which case this feature is labeled with the
            # CLS index).
            if not (
                offsets[token_start_index][0] <= start_char
                and offsets[token_end_index][1] >= end_char
            ):
                tokenized_examples["start_positions"].append(cls_index)
                tokenized_examples["end_positions"].append(cls_index)
            else:
                # Otherwise move the token_start_index and token_end_index to the two ends of the
                # answer.
                # Note: we could go after the last offset if the answer is the last word (edge
                # case).
                while (
                    token_start_index < len(offsets)
                    and offsets[token_start_index][0] <= start_char
                ):
                    token_start_index += 1
                tokenized_examples["start_positions"].append(token_start_index - 1)
                while offsets[token_end_index][1] >= end_char:
                    token_end_index -= 1
                tokenized_examples["end_positions"].append(token_end_index + 1)

    return tokenized_examples

# %%
tokenized_datasets = datasets.map(
    prepare_train_features,
    batched=True,
    remove_columns=datasets.column_names,
    num_proc=3,
)

# %%
train_set = tokenized_datasets.with_format("numpy")[:]  # Load the whole dataset as a dict of numpy arrays
validation_set = train_set

# %%
from transformers import TFAutoModelForQuestionAnswering, TFDistilBertForQuestionAnswering

# model = TFAutoModelForQuestionAnswering.from_pretrained(model_checkpoint)
model = TFDistilBertForQuestionAnswering.from_pretrained(model_checkpoint)
# Out:
# Some layers from the model checkpoint at distilbert-base-uncased were not used when initializing TFDistilBertForQuestionAnswering: ['vocab_projector', 'activation_13', 'vocab_transform', 'vocab_layer_norm']
# - This IS expected if you are initializing TFDistilBertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFDistilBertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some layers of TFDistilBertForQuestionAnswering were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['qa_outputs', 'dropout_39']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
import tensorflow as tf
from tensorflow import keras

optimizer = keras.optimizers.Adam(learning_rate=5e-5)

# %%
# Optionally uncomment the next line for float16 training. Make sence for a GPU what has compute capability of at least 7.0.
keras.mixed_precision.set_global_policy("mixed_float16")

model.compile(optimizer=optimizer)
# Out:
# No loss specified in compile() - the model's internal loss computation will be used as the loss. Don't panic - this is a common way to train TensorFlow models in Transformers! To disable this behaviour please pass a loss argument, or explicitly pass `loss=None` if you do not want your model to compute a loss.

# %%
# model.fit(train_set, validation_data=validation_set, epochs=100, batch_size=1)
# # max_length = 896  # The maximum length of a feature (question and context)
# # doc_stride = (
# #     128  # The authorized overlap between two part of the context when splitting
# # )
# model.fit(train_set, validation_data=validation_set, epochs=250, batch_size=1)
model.fit(train_set, validation_data=validation_set, epochs=250, batch_size=1)
# Out:
# Epoch 1/250
# 5/5 [==============================] - 8s 396ms/step - loss: 6.7156 - val_loss: 6.0227
# Epoch 2/250
# 5/5 [==============================] - 1s 164ms/step - loss: 5.6703 - val_loss: 4.7312
# Epoch 3/250
# 5/5 [==============================] - 1s 162ms/step - loss: 4.4801 - val_loss: 3.4418
# Epoch 4/250
# 5/5 [==============================] - 1s 166ms/step - loss: 3.2820 - val_loss: 2.5355
# Epoch 5/250
# 5/5 [==============================] - 1s 163ms/step - loss: 2.3227 - val_loss: 1.4735
# Epoch 6/250
# 5/5 [==============================] - 1s 168ms/step - loss: 1.3169 - val_loss: 0.6284
# Epoch 7/250
# 5/5 [==============================] - 1s 163ms/step - loss: 0.5565 - val_loss: 0.2241
# Epoch 8/250
# 5/5 [==============================] - 1s 163ms/step - loss: 0.2568 - val_loss: 0.0834
# Epoch 9/250
# 5/5 [==============================] - 1s 159ms/step - loss: 0.2253 - val_loss: 0.0897
# Epoch 10/250
# 5/5 [==============================] - 1s 158ms/step - loss: 0.6092 - val_loss: 0.1310
# Epoch 11/250
# 5/5 [==============================] - 1s 158ms/step - loss: 0.5582 - val_loss: 0.1554
# Epoch 12/250
# 5/5 [==============================] - 1s 164ms/step - loss: 0.3640 - val_loss: 0.0302
# Epoch 13/250
# 5/5 [==============================] - 1s 164ms/step - loss: 0.1022 - val_loss: 0.0612
# Epoch 14/250
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0787 - val_loss: 0.0615
# Epoch 15/250
# 5/5 [==============================] - 1s 160ms/step - loss: 0.3373 - val_loss: 0.0580
# Epoch 16/250
# 5/5 [==============================] - 1s 162ms/step - loss: 0.1106 - val_loss: 0.0366
# Epoch 17/250
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0380 - val_loss: 0.0242
# Epoch 18/250
# 5/5 [==============================] - 1s 162ms/step - loss: 0.0504 - val_loss: 0.0189
# Epoch 19/250
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0256 - val_loss: 0.0139
# Epoch 20/250
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0198 - val_loss: 0.0111
# Epoch 21/250
# 5/5 [==============================] - 1s 162ms/step - loss: 0.0160 - val_loss: 0.0096
# Epoch 22/250
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0144 - val_loss: 0.0085
# Epoch 23/250
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0127 - val_loss: 0.0076
# Epoch 24/250
# 5/5 [==============================] - 1s 166ms/step - loss: 0.0258 - val_loss: 0.0075
# Epoch 25/250
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0128 - val_loss: 0.0076
# Epoch 26/250
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0105 - val_loss: 0.0072
# Epoch 27/250
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0146 - val_loss: 0.0065
# Epoch 28/250
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0091 - val_loss: 0.0059
# Epoch 29/250
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0101 - val_loss: 0.0054
# Epoch 30/250
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0083 - val_loss: 0.0050
# Epoch 31/250
# 5/5 [==============================] - 1s 162ms/step - loss: 0.0087 - val_loss: 0.0047
# Epoch 32/250
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0073 - val_loss: 0.0045
# Epoch 33/250
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0072 - val_loss: 0.0043
# Epoch 34/250
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0079 - val_loss: 0.0041
# Epoch 35/250
# 5/5 [==============================] - 1s 167ms/step - loss: 0.0066 - val_loss: 0.0039
# Epoch 36/250
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0072 - val_loss: 0.0038
# Epoch 37/250
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0065 - val_loss: 0.0037
# Epoch 38/250
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0063 - val_loss: 0.0035
# Epoch 39/250
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0056 - val_loss: 0.0034
# Epoch 40/250
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0062 - val_loss: 0.0034
# Epoch 41/250
# 5/5 [==============================] - 1s 162ms/step - loss: 0.0055 - val_loss: 0.0033
# Epoch 42/250
# 5/5 [==============================] - 1s 162ms/step - loss: 0.0048 - val_loss: 0.0032
# Epoch 43/250
# 5/5 [==============================] - 1s 161ms/step - loss: 0.0053 - val_loss: 0.0031
# Epoch 44/250
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0053 - val_loss: 0.0031
# Epoch 45/250
# 5/5 [==============================] - 1s 167ms/step - loss: 0.0049 - val_loss: 0.0030
# Epoch 46/250
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0049 - val_loss: 0.0029
# Epoch 47/250
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0047 - val_loss: 0.0029
# Epoch 48/250
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0049 - val_loss: 0.0028
# Epoch 49/250
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0046 - val_loss: 0.0027
# Epoch 50/250
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0046 - val_loss: 0.0027
# Epoch 51/250
# 5/5 [==============================] - 1s 167ms/step - loss: 0.0044 - val_loss: 0.0026
# Epoch 52/250
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0046 - val_loss: 0.0026
# Epoch 53/250
# 5/5 [==============================] - 1s 167ms/step - loss: 0.0043 - val_loss: 0.0025
# Epoch 54/250
# 5/5 [==============================] - 1s 166ms/step - loss: 0.0043 - val_loss: 0.0025
# Epoch 55/250
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0040 - val_loss: 0.0024
# Epoch 56/250
# 5/5 [==============================] - 1s 166ms/step - loss: 0.0058 - val_loss: 0.0024
# Epoch 57/250
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0040 - val_loss: 0.0023
# Epoch 58/250
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0037 - val_loss: 0.0023
# Epoch 59/250
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0038 - val_loss: 0.0023
# Epoch 60/250
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0036 - val_loss: 0.0022
# Epoch 61/250
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0039 - val_loss: 0.0022
# Epoch 62/250
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0036 - val_loss: 0.0021
# Epoch 63/250
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0038 - val_loss: 0.0021
# Epoch 64/250
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0036 - val_loss: 0.0021
# Epoch 65/250
# 5/5 [==============================] - 1s 166ms/step - loss: 0.0032 - val_loss: 0.0020
# Epoch 66/250
# 5/5 [==============================] - 1s 167ms/step - loss: 0.0035 - val_loss: 0.0020
# Epoch 67/250
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0033 - val_loss: 0.0020
# Epoch 68/250
# 5/5 [==============================] - 1s 166ms/step - loss: 0.0031 - val_loss: 0.0020
# Epoch 69/250
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0036 - val_loss: 0.0019
# Epoch 70/250
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0040 - val_loss: 0.0019
# Epoch 71/250
# 5/5 [==============================] - 1s 166ms/step - loss: 0.0036 - val_loss: 0.0019
# Epoch 72/250
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0031 - val_loss: 0.0018
# Epoch 73/250
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0036 - val_loss: 0.0018
# Epoch 74/250
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0031 - val_loss: 0.0018
# Epoch 75/250
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0030 - val_loss: 0.0018
# Epoch 76/250
# 5/5 [==============================] - 1s 167ms/step - loss: 0.0031 - val_loss: 0.0017
# Epoch 77/250
# 5/5 [==============================] - 1s 166ms/step - loss: 0.0026 - val_loss: 0.0017
# Epoch 78/250
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0037 - val_loss: 0.0017
# Epoch 79/250
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0031 - val_loss: 0.0017
# Epoch 80/250
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0027 - val_loss: 0.0016
# Epoch 81/250
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0027 - val_loss: 0.0016
# Epoch 82/250
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0027 - val_loss: 0.0016
# Epoch 83/250
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0038 - val_loss: 0.0016
# Epoch 84/250
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0025 - val_loss: 0.0015
# Epoch 85/250
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0026 - val_loss: 0.0015
# Epoch 86/250
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0028 - val_loss: 0.0015
# Epoch 87/250
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0031 - val_loss: 0.0015
# Epoch 88/250
# 5/5 [==============================] - 1s 162ms/step - loss: 0.0022 - val_loss: 0.0015
# Epoch 89/250
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0028 - val_loss: 0.0014
# Epoch 90/250
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0023 - val_loss: 0.0014
# Epoch 91/250
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0021 - val_loss: 0.0014
# Epoch 92/250
# 5/5 [==============================] - 1s 166ms/step - loss: 0.0026 - val_loss: 0.0014
# Epoch 93/250
# 5/5 [==============================] - 1s 166ms/step - loss: 0.0024 - val_loss: 0.0014
# Epoch 94/250
# 5/5 [==============================] - 1s 166ms/step - loss: 0.0027 - val_loss: 0.0014
# Epoch 95/250
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0023 - val_loss: 0.0013
# Epoch 96/250
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0024 - val_loss: 0.0013
# Epoch 97/250
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0022 - val_loss: 0.0013
# Epoch 98/250
# 5/5 [==============================] - 1s 162ms/step - loss: 0.0024 - val_loss: 0.0013
# Epoch 99/250
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0021 - val_loss: 0.0013
# Epoch 100/250
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0022 - val_loss: 0.0013
# Epoch 101/250
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 102/250
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 103/250
# 5/5 [==============================] - 1s 162ms/step - loss: 0.0023 - val_loss: 0.0012
# Epoch 104/250
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0021 - val_loss: 0.0012
# Epoch 105/250
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 106/250
# 5/5 [==============================] - 1s 166ms/step - loss: 0.0019 - val_loss: 0.0012
# Epoch 107/250
# 5/5 [==============================] - 1s 166ms/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 108/250
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 109/250
# 5/5 [==============================] - 1s 167ms/step - loss: 0.0016 - val_loss: 0.0011
# Epoch 110/250
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0020 - val_loss: 0.0011
# Epoch 111/250
# 5/5 [==============================] - 1s 167ms/step - loss: 0.0020 - val_loss: 0.0011
# Epoch 112/250
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0018 - val_loss: 0.0011
# Epoch 113/250
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0021 - val_loss: 0.0011
# Epoch 114/250
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 115/250
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0020 - val_loss: 0.0011
# Epoch 116/250
# 5/5 [==============================] - 1s 166ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 117/250
# 5/5 [==============================] - 1s 166ms/step - loss: 0.0018 - val_loss: 0.0010
# Epoch 118/250
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0022 - val_loss: 0.0010
# Epoch 119/250
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0020 - val_loss: 0.0010
# Epoch 120/250
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0019 - val_loss: 0.0010
# Epoch 121/250
# 5/5 [==============================] - 1s 166ms/step - loss: 0.0023 - val_loss: 9.9535e-04
# Epoch 122/250
# 5/5 [==============================] - 1s 167ms/step - loss: 0.0016 - val_loss: 9.8486e-04
# Epoch 123/250
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0018 - val_loss: 9.7389e-04
# Epoch 124/250
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0023 - val_loss: 9.6407e-04
# Epoch 125/250
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0015 - val_loss: 9.5692e-04
# Epoch 126/250
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0017 - val_loss: 9.4681e-04
# Epoch 127/250
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0016 - val_loss: 9.3803e-04
# Epoch 128/250
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0016 - val_loss: 9.2926e-04
# Epoch 129/250
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0019 - val_loss: 9.2077e-04
# Epoch 130/250
# 5/5 [==============================] - 1s 166ms/step - loss: 0.0021 - val_loss: 9.1057e-04
# Epoch 131/250
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0015 - val_loss: 9.0160e-04
# Epoch 132/250
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0014 - val_loss: 8.9226e-04
# Epoch 133/250
# 5/5 [==============================] - 1s 167ms/step - loss: 0.0016 - val_loss: 8.8329e-04
# Epoch 134/250
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0018 - val_loss: 8.7528e-04
# Epoch 135/250
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0014 - val_loss: 8.6555e-04
# Epoch 136/250
# 5/5 [==============================] - 1s 166ms/step - loss: 0.0014 - val_loss: 8.5869e-04
# Epoch 137/250
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0015 - val_loss: 8.5039e-04
# Epoch 138/250
# 5/5 [==============================] - 1s 166ms/step - loss: 0.0020 - val_loss: 8.4257e-04
# Epoch 139/250
# 5/5 [==============================] - 1s 166ms/step - loss: 0.0016 - val_loss: 8.3456e-04
# Epoch 140/250
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0015 - val_loss: 8.2846e-04
# Epoch 141/250
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0014 - val_loss: 8.2226e-04
# Epoch 142/250
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0013 - val_loss: 8.1711e-04
# Epoch 143/250
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0015 - val_loss: 8.0786e-04
# Epoch 144/250
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0014 - val_loss: 8.0023e-04
# Epoch 145/250
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0014 - val_loss: 7.9384e-04
# Epoch 146/250
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0013 - val_loss: 7.8740e-04
# Epoch 147/250
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0015 - val_loss: 7.8001e-04
# Epoch 148/250
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0013 - val_loss: 7.7491e-04
# Epoch 149/250
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0014 - val_loss: 7.6733e-04
# Epoch 150/250
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0013 - val_loss: 7.6113e-04
# Epoch 151/250
# 5/5 [==============================] - 1s 167ms/step - loss: 0.0014 - val_loss: 7.5488e-04
# Epoch 152/250
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0013 - val_loss: 7.4906e-04
# Epoch 153/250
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0012 - val_loss: 7.4205e-04
# Epoch 154/250
# 5/5 [==============================] - 1s 167ms/step - loss: 0.0016 - val_loss: 7.3543e-04
# Epoch 155/250
# 5/5 [==============================] - 1s 166ms/step - loss: 0.0014 - val_loss: 7.2927e-04
# Epoch 156/250
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0012 - val_loss: 7.2460e-04
# Epoch 157/250
# 5/5 [==============================] - 1s 167ms/step - loss: 0.0014 - val_loss: 7.1750e-04
# Epoch 158/250
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0013 - val_loss: 7.1254e-04
# Epoch 159/250
# 5/5 [==============================] - 1s 167ms/step - loss: 0.0014 - val_loss: 7.0763e-04
# Epoch 160/250
# 5/5 [==============================] - 1s 167ms/step - loss: 0.0011 - val_loss: 7.0014e-04
# Epoch 161/250
# 5/5 [==============================] - 1s 167ms/step - loss: 0.0018 - val_loss: 6.9547e-04
# Epoch 162/250
# 5/5 [==============================] - 1s 166ms/step - loss: 0.0013 - val_loss: 6.9089e-04
# Epoch 163/250
# 5/5 [==============================] - 1s 166ms/step - loss: 0.0012 - val_loss: 6.8717e-04
# Epoch 164/250
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0011 - val_loss: 6.8259e-04
# Epoch 165/250
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0012 - val_loss: 6.7720e-04
# Epoch 166/250
# 5/5 [==============================] - 1s 167ms/step - loss: 0.0011 - val_loss: 6.7248e-04
# Epoch 167/250
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0011 - val_loss: 6.6748e-04
# Epoch 168/250
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0012 - val_loss: 6.6400e-04
# Epoch 169/250
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0013 - val_loss: 6.5818e-04
# Epoch 170/250
# 5/5 [==============================] - 1s 166ms/step - loss: 0.0012 - val_loss: 6.5403e-04
# Epoch 171/250
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0011 - val_loss: 6.5012e-04
# Epoch 172/250
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0011 - val_loss: 6.4754e-04
# Epoch 173/250
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0012 - val_loss: 6.4254e-04
# Epoch 174/250
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0011 - val_loss: 6.3872e-04
# Epoch 175/250
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0012 - val_loss: 6.3405e-04
# Epoch 176/250
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0013 - val_loss: 6.2957e-04
# Epoch 177/250
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0012 - val_loss: 6.2604e-04
# Epoch 178/250
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0011 - val_loss: 6.2194e-04
# Epoch 179/250
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0011 - val_loss: 6.1841e-04
# Epoch 180/250
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0010 - val_loss: 6.1398e-04
# Epoch 181/250
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0011 - val_loss: 6.1007e-04
# Epoch 182/250
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0012 - val_loss: 6.0701e-04
# Epoch 183/250
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0011 - val_loss: 6.0229e-04
# Epoch 184/250
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0012 - val_loss: 5.9958e-04
# Epoch 185/250
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0014 - val_loss: 5.9547e-04
# Epoch 186/250
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0010 - val_loss: 5.9171e-04
# Epoch 187/250
# 5/5 [==============================] - 1s 166ms/step - loss: 0.0011 - val_loss: 5.8846e-04
# Epoch 188/250
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0010 - val_loss: 5.8422e-04
# Epoch 189/250
# 5/5 [==============================] - 1s 167ms/step - loss: 9.5224e-04 - val_loss: 5.8098e-04
# Epoch 190/250
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0011 - val_loss: 5.7640e-04
# Epoch 191/250
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0012 - val_loss: 5.7344e-04
# Epoch 192/250
# 5/5 [==============================] - 1s 163ms/step - loss: 9.8810e-04 - val_loss: 5.6987e-04
# Epoch 193/250
# 5/5 [==============================] - 1s 164ms/step - loss: 0.
# 5/5 [==============================] - 1s 162ms/step - loss: 6.7477e-04 - val_loss: 4.2324e-04
# Epoch 248/250
# 5/5 [==============================] - 1s 164ms/step - loss: 9.2516e-04 - val_loss: 4.2162e-04
# Epoch 249/250
# 5/5 [==============================] - 1s 165ms/step - loss: 8.0442e-04 - val_loss: 4.1957e-04
# Epoch 250/250
# 5/5 [==============================] - 1s 168ms/step - loss: 8.0357e-04 - val_loss: 4.1790e-04

# %%
def get_answer(context, question):
    inputs = tokenizer([context], [question], return_tensors="np")
    outputs = model(inputs)
    start_position = tf.argmax(outputs.start_logits, axis=1)
    end_position = tf.argmax(outputs.end_logits, axis=1)
    answer = inputs["input_ids"][0, int(start_position) : int(end_position) + 1]
    return tokenizer.decode(answer)

# %%
import os

for x in os.listdir("data/courses_exams/"):
    if not x.endswith(".txt"):
        continue
    print(f"{'='*15}{x}")
    # Prints only text file present in My Folder
    with open(f"data/courses_exams/{x}", "r") as f:
        context = f.read()
        print(f'{"-"*10}Courses:')
        print(get_answer(context, "what courses are listed?"))
# Out:
# ===============1.txt
# ----------Courses:
# 2021 mipt school of deep learning fpmi mipt, deep learning 2019 mipt mckinsey, data science in consulting 2019 stepik. org samsung research center, neural networks and computer vision 2019 stepik. org bioinformatics institute, introduction to data science and machine learning
# ===============2.txt
# ----------Courses:
# 2018 hse fkn, minor " data mining " 2018 coursera hse & university of california, data structures and algorithms 2017 sololearn - introduction in sql 2016 coursera hse introduction in python
# ===============3.txt
# ----------Courses:
# 2018 fast. ai fast. ai, data science 2017 changellenge summer school changellenge, consultant 2017 estiem international student organization, coordinator 2017 machine learning courses data camp, machine learning 2016 tinkoff data tinkoff bank, data analysis 2016 preparation for ielts windsor english 2016 data analysis and machine learning yandex, data scientist 2015 best group moscow international student organization, organization
# ===============4.txt
# ----------Courses:
# [CLS] data scientist $ 3, 000 on hand specializations : analyst data scientist employment : full time work schedule : full time, remote work experience 2 years 11 months april 2021 - present 2 years 4 months amberdata data scientist user data analysis december 2020 — april 2021 5 months sberbank www. sbrf. ru financial sector... show more data scientist development of machine learning
# ===============5.txt
# ----------Courses:
# 2023 data science professional certificate ibm, data science, machine learning, deep learning 2023 financial markets yale university, market prediction analysis 2020 computers, waves and simulations ludwig - maxmilians university, forward modeling of seismic wave propagation
# ===============no_courses_1.txt
# ----------Courses:
# [CLS]
# ===============no_courses_2.txt
# ----------Courses:
# [CLS]
# ===============no_courses_3.txt
# ----------Courses:
# [CLS]

# %%
from datetime import datetime
output_folder_name = "models/" + datetime.now().strftime("%Y%m%d-%H%M%S")

TFDistilBertForQuestionAnswering.save_pretrained(model, output_folder_name)
tokenizer.save_pretrained(output_folder_name)
# Out:
# ('models/20230703-220638\\tokenizer_config.json',
#  'models/20230703-220638\\special_tokens_map.json',
#  'models/20230703-220638\\vocab.txt',
#  'models/20230703-220638\\added_tokens.json',
#  'models/20230703-220638\\tokenizer.json')
